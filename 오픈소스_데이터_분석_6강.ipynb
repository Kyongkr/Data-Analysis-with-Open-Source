# %% [markdown]
# <a href="https://colab.research.google.com/github/Kyongkr/Data-Analysis-with-Open-Source/blob/main/%EC%98%A4%ED%94%88%EC%86%8C%EC%8A%A4_%EB%8D%B0%EC%9D%B4%ED%84%B0_%EB%B6%84%EC%84%9D_6%EA%B0%95.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 오픈소스 기반 데이터 분석 6강 - 데이터 전처리 1

# %% [markdown]
# ### 6-1 데이터 훑어보기

# %%
import pandas as pd
import numpy as np

data = {
    'name': ['김민수', '이지영', '박준호', '최서연', '정도윤'],
    'age': [25, 30, 28, 22, 35],
    'city': ['서울', '부산', '인천', '서울', '대전'],
    'score': [90, 85, 95, 80, np.nan]
}
df = pd.DataFrame(data)

# 데이터 측정
df.describe()

# 모든 데이터 타입 측정
df.describe(include='all')

# 수치형 데이터 측정
df.describe(include=[np.number])

# 범주형 데이터 측정
df.describe(include=['object'])

# 특정 열 분석
df['score'].describe()

# %% [markdown]
# ### 6-2 DataFrame 열 선택 및 **조작**

# %%
import pandas as pd

data = {
    "이름": ["김철수", "이영희", "박민수", "최지훈", "정소희"],
    "학년": [1, 2, 3, 4, 2],
    "학점": [4.2, 3.8, 4.5, 3.9, 3.5],
    "학과": ["컴퓨터공학", "경영학", "전자공학", "의학", "심리학"],
    "동아리": ["프로그래밍", "독서토론", "로봇공학", "봉사활동", "음악감상"]
}
df = pd.DataFrame(data)

# 특정 열 선택
selected_col = df[['이름', '학과', '학점']]
selected_col
# DataFrame 열순서 변경
reodered_col = df[['학과', '이름', '학년', '학점', '동아리']]
reodered_col
# DataFrame 열이름 변경
df_rename = df.rename(columns={'이름': '학생명', '학점': '평점', '동아리': '과외활동'})
df_rename
# Out:
#    학생명  학년   평점     학과   과외활동
# 0  김철수   1  4.2  컴퓨터공학  프로그래밍
# 1  이영희   2  3.8    경영학   독서토론
# 2  박민수   3  4.5   전자공학   로봇공학
# 3  최지훈   4  3.9     의학   봉사활동
# 4  정소희   2  3.5    심리학   음악감상

# %% [markdown]
# ### 6-3 DataFrame 행 선택

# %%
import pandas as pd

data = {
    "이름": ["김철수", "이영희", "박민수", "최지훈", "정소희"],
    "학년": [1, 2, 3, 4, 2],
    "학점": [4.2, 3.8, 4.5, 3.9, 3.5],
    "학과": ["컴퓨터공학", "경영학", "전자공학", "의학", "심리학"],
    "동아리": ["프로그래밍", "독서토론", "로봇공학", "봉사활동", "음악감상"]
}

#DataFrame 인덱스 지정
df = pd.DataFrame(data)
df = df.set_index('이름')
df

#DataFrame 행 선택
df.loc['김철수']
df.loc[['김철수', '이영희']]
df.loc['김철수':'박민수']

#DataFrame 위치 기반 행 선택
df.iloc[1]
df.iloc[[2,3]]
df.iloc[1:3]

#DataFrame 조건 기반 선택
df.loc[[True, False, True, False, False]]
print(df['학점'])
df.loc[df['학점'] >= 4.0]
df[df['학년'] == 2]
df[(df['학년'] == 2) & (df['학점'] >= 3.7 )]
# Out:
# 이름
# 김철수    4.2
# 이영희    3.8
# 박민수    4.5
# 최지훈    3.9
# 정소희    3.5
# Name: 학점, dtype: float64
#      학년   학점   학과   동아리
# 이름
# 이영희   2  3.8  경영학  독서토론

# %% [markdown]
# ### 6-4 DataFrame 정렬

# %%
import pandas as pd

data = {
    "이름": ["김철수", "이영희", "박민수", "최지훈", "정소희"],
    "학년": [1, 2, 3, 4, 2],
    "학점": [4.2, 3.8, 4.5, 3.9, 3.5],
    "학과": ["컴퓨터공학", "경영학", "전자공학", "의학", "심리학"],
    "동아리": ["프로그래밍", "독서토론", "로봇공학", "봉사활동", "음악감상"]
}

#DataFrame 인덱스 지정
df = pd.DataFrame(data).set_index('이름')
df

#DataFrame 단일 열 오름차순, 내림차순 정렬
df.sort_values(by='학점')
df.sort_values(by='학점', ascending=False)

#DataFrame 복수 열 오름차순, 내림차순 정렬
df.sort_values(by=['학년', '학점'], ascending=[True, False])

#DataFrame 인덱스 기분 오른차순, 내림차순 정렬
df.sort_index(ascending=False)
# Out:
#      학년   학점     학과    동아리
# 이름
# 최지훈   4  3.9     의학   봉사활동
# 정소희   2  3.5    심리학   음악감상
# 이영희   2  3.8    경영학   독서토론
# 박민수   3  4.5   전자공학   로봇공학
# 김철수   1  4.2  컴퓨터공학  프로그래밍

# %% [markdown]
# ## 6-5 실습 시나리오 - Kaggle을 활용한 데이터 수집 및 측정

# %% [markdown]
# - Kaggle([https://www.kaggle.com](https://www.kaggle.com)) 회원 가입
# - Kaggle 접근 토큰 생성(API 키)

# %% [markdown]
# ### Kaggle API 키 업로드

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-21d92a66-a823-4612-a44e-aa812412f985" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-21d92a66-a823-4612-a44e-aa812412f985">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# ### Kaggle API 키 사용을 위한 Colab 환경 설정

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %% [markdown]
# ### Kaggle 데이터셋 다운로드

# %%
# !kaggle competitions download -c store-sales-time-series-forecasting

# !unzip store-sales-time-series-forecasting.zip
# Out:
# ...
#   0% 0.00/21.4M [00:00<?, ?B/s]
# 100% 21.4M/21.4M [00:00<00:00, 1.27GB/s]
# Archive:  store-sales-time-series-forecasting.zip
#   inflating: holidays_events.csv
#   inflating: oil.csv
#   inflating: sample_submission.csv
#   inflating: stores.csv
#   inflating: test.csv
#   inflating: train.csv
#   inflating: transactions.csv

# %% [markdown]
# ### Kaggle 데이터셋 DataFrame 로드 및 살펴보기

# %%
import pandas as pd

# Grocery Sales 데이터 DataFrame 로드
train = pd.read_csv('train.csv')
stores = pd.read_csv('stores.csv')
transactions = pd.read_csv('transactions.csv')
oil = pd.read_csv('oil.csv')
holidays_events = pd.read_csv('holidays_events.csv')

# 판매 데이터 살펴보기
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000888 entries, 0 to 3000887
# Data columns (total 6 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   id           int64
#  1   date         object
#  2   store_nbr    int64
#  3   family       object
#  4   sales        float64
#  5   onpromotion  int64
# dtypes: float64(1), int64(3), object(2)
# memory usage: 137.4+ MB

# %% [markdown]
# ### Kaggle 데이터셋 측정

# %%
# 판매 데이터 기본 통계량
train.describe()

# 매장 데이터 기본 정보
stores.head()

# 원유 가격 데이터 기본 정보
oil.head()
# Out:
#          date  dcoilwtico
# 0  2013-01-01         NaN
# 1  2013-01-02       93.14
# 2  2013-01-03       92.97
# 3  2013-01-04       93.12
# 4  2013-01-07       93.20

# %% [markdown]
# 1-2 Python을 사용하여 API를 호출하는 코드를 작성하고, 2015년 1월부터 2024년 12월까지의 개
# 인 유형의 현년 전기, 가스, 수도, 지역난방 에너지 사용량 데이터를 수집하는 프로그램을 작성하
# 시오. API 호출 성공을 확인할 수 있는 실행 결과를 캡처하여 첨부하시오. (7점)

# %%
import requests
import pandas as pd
import numpy as np
import time
import matplotlib.pyplot as plt
plt.rc('font', family='NanumBarunGothic')


# 1-2
# 기초값 설정
url = "http://openapi.seoul.go.kr:8088/{key}/json/energyUseDataSummaryInfo/1/10/{year}/{month}"
api_key = "58444d444a6f75743731714964444e"
year_start, year_end = 2015, 2016

# 데이터 수집
data_list = []

print(f"서울시 개인 에너지 사용량 수집({year_start}.01 ~ {year_end}.12)")
print("-" * 41)


try:

    # 2015년 ~ 2024년까지
    for year in range(year_start, year_end + 1):
        for month in range(1, 13):

            # api_url 포맷에 사용할 월 문자
            month_str = str(month).zfill(2)

            # API 호출 URL
            api_url = url.format(
                key=api_key,
                year=year,
                month=month_str
            )

            print(f"       -> 호출 중: {year}년 {month:02d}월 ~ ", end="")

            # API 호출
            response = requests.get(api_url)

            # 응답 상태 코드 확인
            if response.status_code == 200:
                # JSON 데이터 로드
                data = response.json()

                # API 호출 성공 여부 확인
                if 'energyUseDataSummaryInfo' in data:
                    rows = data['energyUseDataSummaryInfo']['row']
                    personal_data = next((row for row in rows if row.get('MM_TYPE') == '개인'), None)

                    if personal_data:
                        data_list.append({
                            '날짜': year * 100 + month,
                            '전기': personal_data.get('EUS'),
                            '가스': personal_data.get('GUS'),
                            '수도': personal_data.get('WUS'),
                            '지역난방': personal_data.get('HUS'),
                            })
                        print("성공")

                    else:
                        print("개인 유형 없음")

            else:
                print("API 호출 실패")

            time.sleep(0.1)

except requests.exceptions.RequestException:
    print("API 요청 실패")
# Out:
# 서울시 개인 에너지 사용량 수집(2015.01 ~ 2016.12)
# -----------------------------------------
#        -> 호출 중: 2015년 01월 ~ 성공
#        -> 호출 중: 2015년 02월 ~ 성공
#        -> 호출 중: 2015년 03월 ~ 성공
#        -> 호출 중: 2015년 04월 ~ 성공
#        -> 호출 중: 2015년 05월 ~ 성공
#        -> 호출 중: 2015년 06월 ~ 성공
#        -> 호출 중: 2015년 07월 ~ 성공
#        -> 호출 중: 2015년 08월 ~ 성공
#        -> 호출 중: 2015년 09월 ~ 성공
#        -> 호출 중: 2015년 10월 ~ 성공
#        -> 호출 중: 2015년 11월 ~ 성공
#        -> 호출 중: 2015년 12월 ~ 성공
#        -> 호출 중: 2016년 01월 ~ 성공
#        -> 호출 중: 2016년 02월 ~ 성공
#        -> 호출 중: 2016년 03월 ~ 성공
#        -> 호출 중: 2016년 04월 ~ 성공
#        -> 호출 중: 2016년 05월 ~ 성공
#        -> 호출 중: 2016년 06월 ~ 성공
#        -> 호출 중: 2016년 07월 ~ 성공
#        -> 호출 중: 2016년 08월 ~ 성공
#        -> 호출 중: 2016년 09월 ~ 성공
#        -> 호출 중: 2016년 10월 ~ 성공
#        -> 호출 중: 2016년 11월 ~ 성공
#        -> 호출 중: 2016년 12월 ~ 성공

# %% [markdown]
# 문제 2-1 수집한 JSON 형태의 데이터를 pandas DataFrame으로 변환하고, 데이터의 기본 정보를 출력
# 하는 코드와 실행 결과를 첨부하시오.

# %%
df = pd.DataFrame(data_list)
df.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3724394253.py in <cell line: 0>()
# ----> 1 df = pd.DataFrame(data_list)
#       2 df.info()
#
# NameError: name 'pd' is not defined

# %% [markdown]
# 2-2 연도별, 계절별 분석을 위해 날짜 컬럼을 활용하여 연도(year)와 계절(season) 컬럼을 추가하
# 는 전처리 코드를 작성하고, 변환 결과를 확인할 수 있는 출력 결과를 첨부하시오.
# ※ 계절 구분: 봄(3-5월), 여름(6-8월), 가을(9-11월), 겨울(12-2월) (4점)

# %%
# '연도' 칼럼
df['연도'] = df['날짜'].str[:4]

# 계절의 조건과 결과를 정의
month_num = df['날짜'].str[4:].astype(int)

conditions = [
    (month_num >= 3) & (month_num <= 5), # 봄
    (month_num >= 6) & (month_num <= 8), # 여름
    (month_num >= 9) & (month_num <= 11) # 가을
]
choices = ['봄', '여름', '가을']

# '계절' 칼럼 추가, 나머지는 '겨울'
df['계절'] = np.select(conditions, choices, default='겨울')
df.head()
# Out:
#        날짜         전기        가스            수도          지역난방    연도  계절
# 0  201501  193784708  59133720  12819757.886  22740838.937  2015  겨울
# 1  201502  189974230  56487358  12656888.218  18793320.213  2015  겨울
# 2  201503  175215719  49984873  12655474.249  13826348.508  2015   봄
# 3  201504  183891769  37306841  12954773.246   5836002.885  2015   봄
# 4  201505  177289769  22060892  13086734.214   1320895.801  2015   봄

# %% [markdown]
# 3-1 연도별 에너지 사용 총 사용량(전기+가스+수도+지역난방) 변화량을 선 그래프로 시각화하고,
# 그래프에 자신의 학번 뒤 4자리를 제목에 포함하여 저장하시오. (예: "연도별 에너지 사용 총액 변
# 화 - 1234") 시각화 코드와 생성된 그래프를 첨부하시오. (4점)

# %%
import matplotlib.pyplot as plt
plt.rc('font', family='NanumBarunGothic')


# 에너지 사용량 칼럼을 수치형 변환
numeric_cols = ['전기', '가스', '수도', '지역난방']
df[numeric_cols] = df[numeric_cols].apply(pd.to_numeric, errors='coerce')

# 연도별 총 사용량
df['총 사용량'] = df[numeric_cols].sum(axis=1)

# '연도'별로 '총 사용량'을 합산, 새 데이터프레임을 생성
annual_df = df.groupby('연도')['총 사용량'].sum().reset_index()
annual_df.columns = ['연도', '연간 총 사용량']

# X축: 연도, Y축: 연간 총 사용량
plt.figure(figsize=(10, 6))
plt.plot(annual_df['연도'], annual_df['연간 총 사용량'], marker='o', linestyle='-', color='b')

# 제목 설정
plt.title('2015년~2024년 연도별 개인 에너지 총 사용량 변화량 - 6989', fontsize=15)
plt.xlabel('연도', fontsize=12)
plt.ylabel('연간 총 에너지 사용량', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.7)

# X축, Y축 표
plt.xticks(annual_df['연도'], rotation=0)
plt.ticklabel_format(axis='y', style='plain')
plt.tight_layout()
plt.show()
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# ...

# %% [markdown]
# 3-2 계절별 가스 사용량 평균을 막대 그래프로 시각화하고, 각 막대에 구체적인 수치를 표시하시
# 오. 시각화 코드와 생성된 그래프를 첨부하시오. (4점)

# %%
# 계절별 가스 사용량 평균 계산
season_gas_usage_average = df.groupby('계절')['가스'].mean().reindex(['봄', '여름', '가을', '겨울'])

# 막대 그래프 생성
plt.figure(figsize=(10, 6))
bars = plt.bar(season_gas_usage_average.index, season_gas_usage_average.values, color=['deepskyblue', 'orange', 'yellowgreen', 'red'])

# 그래프 제목 및 라벨 설정
plt.title('계절별 평균 가스 사용량', fontsize=15)
plt.xlabel('계절', fontsize=12)
plt.ylabel('평균 가스 사용량', fontsize=12)
plt.ticklabel_format(axis='y', style='plain')

# 각 막대 위에 구체적인 수치 표시
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width() / 2, height, f'{height:.2f}',
             ha='center', va='bottom', fontsize=10, color='black')

plt.tight_layout()
plt.show()
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# /tmp/ipython-input-2956855094.py:20: UserWarning: Glyph 48388 (\N{HANGUL SYLLABLE BOM}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# /tmp/ipython-input-2956855094.py:20: UserWarning: Glyph 50668 (\N{HANGUL SYLLABLE YEO}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-2956855094.py:20: UserWarning: Glyph 47492 (\N{HANGUL SYLLABLE REUM}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# /tmp/ipython-input-2956855094.py:20: UserWarning: Glyph 44032 (\N{HANGUL SYLLABLE GA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# ...
